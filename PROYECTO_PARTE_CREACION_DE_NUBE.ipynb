# %% [markdown]
# <a href="https://colab.research.google.com/github/985emily/WORD_CLOUD_PROYECT/blob/master/PROYECTO_PARTE_CREACION_DE_NUBE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CREACIÓN DE LA NUBE
#
#
# *   CAMBIOS A LA HORA DE ALMACENAR LOS TAGS
# *   CREACIÓN DEL METODO PARA LA RELIZACIÓN DE LA NUBE DE PALABRAS

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Import package
from wordcloud import WordCloud, STOPWORDS

from bs4 import BeautifulSoup
import requests
import pandas as pd


print("Ingrese un usuario: ")
usuario = input()
print("NUM DE USUARIO:" +usuario)
page = requests.get("https://es.stackoverflow.com/users/"+usuario)
soup = BeautifulSoup(page.content,'html.parser')

#obtener nombre usuario
Nusuario = soup.find('div',class_="grid--cell fw-bold").text
print("NOMBRE: "+Nusuario)


url = "https://es.stackoverflow.com/users/"+usuario+"/"+Nusuario+"?tab=tags" + "&sort=votes&page="


soup = BeautifulSoup(page.content,'html.parser')
td = soup.find_all("td")
 
tags = list()

Ntags = list()


listacomplit = list()
#conseguir el numero de rango


for page in range(1,15):

    print('---', page, '---')

    r = requests.get(url + str(page))
    
    soup = BeautifulSoup(r.content, "html.parser")
    td = soup.find_all("td")
    for i in td:
      tags.append(i.find('a', class_='post-tag').text)
    #Ntags


    for i in td:
      Ntags.append(i.find('div', class_='answer-votes').text)
      
    for i in range(len(tags)):
        if Ntags[i] == "3k" or "2k" or "1k":
          Ntags[i]=2000
        else: 
          Ntags[i]= Ntags

        for k in range(int(Ntags[i])):
              listacomplit.append(tags[i])
        
    print(listacomplit)






# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(20, 10))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    
    plt.axis("off");
    

    # Generate word cloud
    wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS, regexp= r"\S[\S']+" ).generate(' '.join(listacomplit))
    # Plot
    plot_cloud(wordcloud)

# %% [markdown]
# CREACION DE LA PARTE ESTRUCTURAL DEL PROYECTO
#
#
# 1.   BÚSQUEDA Y CREACIÓN DE LINKS DE LAS PÁGINAS DONDE SE REALIZARA LA PARTE PRINCIPAL DEL PROYECTO
# 2.   BÚSQUEDA E INGRESO DE TODAS LAS ETIQUETAS DEL USUARIO A LISTAS PARA SU PRÓXIMA UTILIDAD

# %%
import requests
from bs4 import BeautifulSoup

from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

print("Ingrese un usuario: ")
usuario = input()
print("NUM DE USUARIO:" +usuario)
page = requests.get("https://es.stackoverflow.com/users/"+usuario)
soup = BeautifulSoup(page.content,'html.parser')

#obtener nombre usuario
Nusuario = soup.find('div',class_="grid--cell fw-bold").text
print("NOMBRE: "+Nusuario)


url = "https://es.stackoverflow.com/users/"+usuario+"/"+Nusuario+"?tab=tags" + "&sort=votes&page="


#conseguir el numero de rango

for page in range(16):

   # print('---', page, '---')

    r = requests.get(url + str(page))

    soup = BeautifulSoup(r.content, "html.parser")

    
     #Tags
    tag = soup.find_all('a', class_='post-tag')
    tags = list()
    for i in tag:
          tags.append(i.text)
          n = len(tags)
    print(tags[0:n])
    #Ntags
    Ntag = soup.find_all('div', class_='answer-votes')
    Ntags = list()
    for i in Ntag:
          Ntags.append(i.text)
          num = len(Ntags)
    print(Ntags[0:num])

# %% [markdown]
# CREACION DE LA PARTE ESTRUCTURAL DEL PROYECTO
#
# INGRESO DE USUARIO
# BÚSQUEDA Y CREACIÓN DEL LINK DE LA PÁGINA DONDE SE REALIZARA LA PARTE PRINCIPAL DEL PROYECTO
# BÚSQUEDA DE DATOS DEL USUARIO
# BÚSQUEDA E INGRESO DE LAS ETIQUETAS DEL USUARIO

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

print("Ingrese un usuario: ")
usuario = input()
print("NUM DE USUARIO:" +usuario)
page = requests.get("https://es.stackoverflow.com/users/"+usuario)
soup = BeautifulSoup(page.content,'html.parser')

#obtener nombre usuario
Nusuario = soup.find('div',class_="grid--cell fw-bold").text
print("NOMBRE: "+Nusuario)

page = requests.get("https://es.stackoverflow.com/users/"+usuario+"/"+Nusuario+"?tab=tags")
soup = BeautifulSoup(page.content,'html.parser')
 
#Tags
tag = soup.find_all('a', class_='post-tag')
 
tags = list()

for i in tag:
    tags.append(i.text)
    n = len(tags)
print(tags[0:n])

#Ntags
Ntag = soup.find_all('div', class_='answer-votes')
 
Ntags = list()

for i in Ntag:
    Ntags.append(i.text)
    num = len(Ntags)
print(Ntags[0:num])
